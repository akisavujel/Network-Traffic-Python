# %% [markdown]
# <a href="https://www.kaggle.com/code/akisavujel/networktraffic?scriptVersionId=304589191" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <h1 style="text-align: center; font-family: 'Georgia', serif; font-size: 32px; font-weight: 700; color: inherit; margin: 20px 0 8px 0;">Network Traffic <em style="font-style: italic; color: #2d5a4f;">Data Analysis</em></h1>
#
# <p style="text-align: center; font-size: 12px; color: #999; letter-spacing: 0.15em; text-transform: uppercase; margin: 0;">CC5067NT — Smart Data Discovery</p>
# <br/>
# <img src="https://www.secquest.co.uk/wp-content/uploads/2024/04/network-security-2048x1365.jpg" style="width: 100%; max-width: 600px; border-radius: 12px; display: block; margin: 0 auto; box-shadow: 0 4px 16px rgba(0,0,0,0.15);"/>
# <br/>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Playfair+Display:ital,wght@0,700;1,400&display=swap" rel="stylesheet"/>
#
# <h1 style="text-align: center; font-family: 'Playfair Display', serif; font-size: 64px; margin: 0;">
#   <span style="font-weight: 700; color: inherit;">Data </span>
#   <span style="font-style: italic; color: #b85c38;">Preparation</span>
# </h1>

# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/datasets/akisavujel/network-traffic/ids.csv')

# %%
columns = ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 
           'Total Backward Packets', 'Total Length of Fwd Packets', 
           'Total Length of Bwd Packets', 'Fwd Packet Length Mean', 
           'Bwd Packet Length Mean', 'Flow Bytes/s', 'Flow Packets/s', 
           'Packet Length Mean', 'Packet Length Std', 'Average Packet Size', 
           'Active Mean', 'Idle Mean', 'Label']

# %%
df_filtered = df[columns]

# %%
df_filtered.tail(50).style\
  .background_gradient(cmap='Purples')\
  .highlight_null(color='red')\
  .set_caption('📋 Filtered Dataset')\
  .set_table_styles([{
      'selector': 'caption',
      'props': [('font-size', '14px'),
                ('font-weight', 'bold'),
                ('color', '#2d5a4f')]
  }])
# Out:
# <style type="text/css">
# #T_cc4ed caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2d5a4f;
# }
# ...

# %%
print("=" * 60)
print("   ✅ FILTERED DATAFRAME CREATED SUCCESSFULLY!")
print("=" * 60)
print("   Total Rows    :", df_filtered.shape[0])
print("   Total Columns :", df_filtered.shape[1])
print("=" * 60)
# Out:
# ...
#    ✅ FILTERED DATAFRAME CREATED SUCCESSFULLY!
# ...
#    Total Rows    : 488115
#    Total Columns : 16
# ...

# %%
print("=" * 60)
print("   📋 TOP 3 VALUES OF FILTERED DATASET")
print("=" * 60)
print("\n")
df_filtered.head(3).style.background_gradient(cmap='Greens')
# Out:
# ...
#    📋 TOP 3 VALUES OF FILTERED DATASET
# ...
# <style type="text/css">
# #T_b52b5_row0_col0, #T_b52b5_row0_col2, #T_b52b5_row0_col9, #T_b52b5_row0_col13, #T_b52b5_row0_col14, #T_b52b5_row1_col1, #T_b52b5_row1_col2, #T_b52b5_row1_col3, #T_b52b5_row1_col4, #T_b52b5_row1_col5, #T_b52b5_row1_col6, #T_b52b5_row1_col7, #T_b52b5_row1_col10, #T_b52b5_row1_col11, #T_b52b5_row1_col12, #T_b52b5_row1_col13, #T_b52b5_row1_col14, #T_b52b5_row2_col8, #T_b52b5_row2_col9, #T_b52b5_row2_col13, #T_b52b5_row2_col14 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_b52b5_row0_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_b52b5_row0_col3, #T_b52b5_row0_col5, #T_b52b5_row0_col6, #T_b52b5_row0_col7, #T_b52b5_row0_col10, #T_b52b5_row0_col11, #T_b52b5_row0_col12, #T_b52b5_row1_col0, #T_b52b5_row1_col8, #T_b52b5_row1_col9, #T_b52b5_row2_col1, #T_b52b5_row2_col2, #T_b52b5_row2_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_b52b5_row0_col4 {
# ...

# %%
print("=" * 50)
print("   📐 SHAPE OF NEW DATAFRAME")
print("=" * 50)
print(df_filtered.shape)
# Out:
# ...
#    📐 SHAPE OF NEW DATAFRAME
# ...
# (488115, 16)

# %%
print("=" * 50)
print("   🔍 MISSING VALUES PER COLUMN")
print("=" * 50)
print(df_filtered.isnull().sum())
# Out:
# ...
#    🔍 MISSING VALUES PER COLUMN
# ...
# Destination Port                0
# Flow Duration                   0
# Total Fwd Packets               0
# Total Backward Packets          0
# Total Length of Fwd Packets     0
# Total Length of Bwd Packets     0
# Fwd Packet Length Mean          0
# Bwd Packet Length Mean          0
# Flow Bytes/s                   36
# Flow Packets/s                  0
# Packet Length Mean              0
# Packet Length Std               0
# Average Packet Size             0
# Active Mean                     0
# Idle Mean                       0
# Label                           0
# dtype: int64

# %%
print("=" * 50)
print("   🔍 TOTAL MISSING VALUES")
print("=" * 50)
print(df_filtered.isnull().sum().sum())
# Out:
# ...
#    🔍 TOTAL MISSING VALUES
# ...
# 36

# %%
df_filtered = df_filtered.dropna()

print("=" * 50)
print("   ✅ SHAPE AFTER REMOVING MISSING VALUES")
print("=" * 50)
print(df_filtered.shape)
# Out:
# ...
#    ✅ SHAPE AFTER REMOVING MISSING VALUES
# ...
# (488079, 16)

# %%
print("=" * 50)
print("   🔁 DUPLICATE RECORDS")
print("=" * 50)
print(df_filtered.duplicated())
# Out:
# ...
#    🔁 DUPLICATE RECORDS
# ...
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 488110     True
# 488111     True
# 488112    False
# 488113    False
# 488114    False
# Length: 488079, dtype: bool

# %%
print("=" * 50)
print("   🔁 TOTAL DUPLICATE RECORDS")
print("=" * 50)
print(df_filtered.duplicated().sum())
# Out:
# ...
#    🔁 TOTAL DUPLICATE RECORDS
# ...
# 139389

# %%
print("=" * 50)
print("   📊 TOTAL NUMBER OF COLUMNS")
print("=" * 50)
print(df_filtered.shape[1])
# Out:
# ...
#    📊 TOTAL NUMBER OF COLUMNS
# ...
# 16

# %%
print("=" * 50)
print("   📋 COLUMN NAMES")
print("=" * 50)
for i, col in enumerate(df_filtered.columns, 1):
    print(f"{i}. {col}")
# Out:
# ...
#    📋 COLUMN NAMES
# ...
# 1. Destination Port
# 2. Flow Duration
# 3. Total Fwd Packets
# 4. Total Backward Packets
# 5. Total Length of Fwd Packets
# 6. Total Length of Bwd Packets
# 7. Fwd Packet Length Mean
# 8. Bwd Packet Length Mean
# 9. Flow Bytes/s
# 10. Flow Packets/s
# 11. Packet Length Mean
# 12. Packet Length Std
# 13. Average Packet Size
# 14. Active Mean
# 15. Idle Mean
# 16. Label

# %%
df_filtered['Label'] = df_filtered['Label'].replace({
    'BENIGN': 'Normal Traffic',
    'Infiltration': 'Attack'
})

# %%
print("=" * 50)
print("   🏷️  LABEL VALUES AFTER RENAMING")
print("=" * 50)
print(df_filtered['Label'].unique())
# Out:
# ...
#    🏷️  LABEL VALUES AFTER RENAMING
# ...
# ['Normal Traffic' 'Attack']

# %%
print("=" * 50)
print("   🏷️  LABEL VALUE COUNTS")
print("=" * 50)
print(df_filtered['Label'].value_counts())
# Out:
# ...
#    🏷️  LABEL VALUE COUNTS
# ...
# Label
# Normal Traffic    288548
# Attack            199531
# Name: count, dtype: int64

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Playfair+Display:ital,wght@0,700;1,400&display=swap" rel="stylesheet"/>
#
# <h1 style="text-align: center; font-family: 'Playfair Display', serif; font-size: 64px; margin: 0;">
#   <span style="font-weight: 700; color: inherit;">Data </span>
#   <span style="font-style: italic; color: #b85c38;">Analysis</span>
# </h1>

# %% [markdown]
# <div style="display: flex; gap: 12px; margin: 10px 0;">
#
#   <div style="background: #f7f5f0; padding: 12px 16px; border-radius: 10px; text-align: center; flex: 1;">
#     <p style="color: #999; font-size: 10px; text-transform: uppercase; letter-spacing: 0.1em; margin: 0 0 6px 0;">Total Rows</p>
#     <h3 style="color: #2d5a4f; margin: 0; font-size: 18px;">288602</h3>
#   </div>
#
#   <div style="background: #f7f5f0; padding: 12px 16px; border-radius: 10px; text-align: center; flex: 1;">
#     <p style="color: #999; font-size: 10px; text-transform: uppercase; letter-spacing: 0.1em; margin: 0 0 6px 0;">Total Columns</p>
#     <h3 style="color: #2d5a4f; margin: 0; font-size: 18px;">79</h3>
#   </div>
#
#   <div style="background: #f7f5f0; padding: 12px 16px; border-radius: 10px; text-align: center; flex: 1;">
#     <p style="color: #999; font-size: 10px; text-transform: uppercase; letter-spacing: 0.1em; margin: 0 0 6px 0;">Labels</p>
#     <h3 style="color: #2d5a4f; margin: 0; font-size: 18px;">2</h3>
#   </div>
#
#   <div style="background: #f7f5f0; padding: 12px 16px; border-radius: 10px; text-align: center; flex: 1;">
#     <p style="color: #999; font-size: 10px; text-transform: uppercase; letter-spacing: 0.1em; margin: 0 0 6px 0;">Filtered Columns</p>
#     <h3 style="color: #2d5a4f; margin: 0; font-size: 18px;">16</h3>
#   </div>
#
# </div>

# %%
cols = ['Flow Duration', 'Packet Length Mean']

# %%
sum_result = df_filtered[cols].sum()
mean_result = df_filtered[cols].mean()
std_result = df_filtered[cols].std()
skew_result = df_filtered[cols].skew()
kurt_result = df_filtered[cols].kurt()

# %%
print("=" * 50)
print("   ➕ SUM")
print("=" * 50)
print(sum_result)

print("\n")

print("=" * 50)
print("   📊 MEAN")
print("=" * 50)
print(mean_result)

print("\n")

print("=" * 50)
print("   📉 STANDARD DEVIATION")
print("=" * 50)
print(std_result)

print("\n")

print("=" * 50)
print("   📐 SKEWNESS")
print("=" * 50)
print(skew_result)

print("\n")

print("=" * 50)
print("   📈 KURTOSIS")
print("=" * 50)
print(kurt_result)
# Out:
# ...
#    ➕ SUM
# ...
# Flow Duration         4.364853e+12
# Packet Length Mean    4.175763e+07
# dtype: float64
#
#
# ...
#    📊 MEAN
# ...
# Flow Duration         8.942923e+06
# Packet Length Mean    8.555506e+01
# dtype: float64
#
#
# ...
#    📉 STANDARD DEVIATION
# ...
# Flow Duration         2.748182e+07
# Packet Length Mean    1.738725e+02
# dtype: float64
#
#
# ...
#    📐 SKEWNESS
# ...
# Flow Duration         3.250874
# Packet Length Mean    4.935766
# dtype: float64
#
#
# ...
#    📈 KURTOSIS
# ...
# Flow Duration          9.246791
# Packet Length Mean    34.610512
# dtype: float64

# %%
# The column label contains text variable which doesnot work with corr
correlation_matrix = df_filtered.drop(columns=['Label']).corr()

# %%
print("=" * 50)
print("   🔗 CORRELATION MATRIX")
print("=" * 50)
correlation_matrix.style.background_gradient(cmap='Greens')
# Out:
# ...
#    🔗 CORRELATION MATRIX
# ...
# <style type="text/css">
# #T_f75cd_row0_col0, #T_f75cd_row1_col1, #T_f75cd_row2_col2, #T_f75cd_row3_col3, #T_f75cd_row4_col4, #T_f75cd_row5_col5, #T_f75cd_row6_col6, #T_f75cd_row7_col7, #T_f75cd_row8_col8, #T_f75cd_row9_col9, #T_f75cd_row10_col10, #T_f75cd_row11_col11, #T_f75cd_row12_col12, #T_f75cd_row13_col13, #T_f75cd_row14_col14 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f75cd_row0_col1, #T_f75cd_row0_col2, #T_f75cd_row0_col3, #T_f75cd_row0_col5, #T_f75cd_row0_col7, #T_f75cd_row0_col11, #T_f75cd_row0_col13, #T_f75cd_row0_col14, #T_f75cd_row7_col0, #T_f75cd_row7_col8, #T_f75cd_row7_col9, #T_f75cd_row9_col3, #T_f75cd_row9_col4, #T_f75cd_row9_col5, #T_f75cd_row9_col6, #T_f75cd_row9_col10, #T_f75cd_row9_col12 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_f75cd_row0_col4, #T_f75cd_row0_col12, #T_f75cd_row1_col8, #T_f75cd_row8_col4, #T_f75cd_row9_col2, #T_f75cd_row9_col11, #T_f75cd_row9_col13, #T_f75cd_row14_col8 {
# ...

# %%
corr_pairs = correlation_matrix.unstack() # Convert the corr table to list
corr_pairs = corr_pairs[corr_pairs != 1] # Remove where corr is perfect 1
corr_pairs = corr_pairs.drop_duplicates() # Drop repeated pairs
corr_pairs_sorted = corr_pairs.abs().sort_values(ascending=False)

# %%
print("=" * 50)
print("   🔝 TOP 5 CORRELATED FEATURES")
print("=" * 50)
print(corr_pairs_sorted.head(5).to_string())
# Out:
# ...
#    🔝 TOP 5 CORRELATED FEATURES
# ...
# Packet Length Mean      Average Packet Size            0.995068
# Total Backward Packets  Total Length of Bwd Packets    0.961480
# Total Fwd Packets       Total Backward Packets         0.949848
#                         Total Length of Bwd Packets    0.920007
# Packet Length Mean      Packet Length Std              0.887792

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Playfair+Display:ital,wght@0,700;1,400&display=swap" rel="stylesheet"/>
#
# <h1 style="text-align: center; font-family: 'Playfair Display', serif; font-size: 64px; margin: 0;">
#   <span style="font-weight: 700; color: inherit;">Data </span>
#   <span style="font-style: italic; color: #b85c38;">Exploration</span>
# </h1>

# %%
import matplotlib.pyplot as plt

# %%
label_counts = df_filtered['Label'].value_counts()

# %%
print("=" * 50)
print("   🏷️  LABEL VALUE COUNTS")
print("=" * 50)
print(label_counts)
# Out:
# ...
#    🏷️  LABEL VALUE COUNTS
# ...
# Label
# Normal Traffic    288548
# Attack            199531
# Name: count, dtype: int64

# %%
print("=" * 50)
print("   📊 LABEL PERCENTAGES")
print("=" * 50)
print(round(label_counts / label_counts.sum() * 100, 2))
# Out:
# ...
#    📊 LABEL PERCENTAGES
# ...
# Label
# Normal Traffic    59.12
# Attack            40.88
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6, 4))
plt.bar(label_counts.index, label_counts.values, color=['#c9b8f5', '#f5b8d0'], width=0.5)
plt.title('Frequency of Each Category in Label Column')
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.show()

# %%
avg_flow = df_filtered.groupby('Label')['Flow Duration'].mean()
avg_packet = df_filtered.groupby('Label')['Packet Length Mean'].mean()

# %%
print("=" * 50)
print("   ⏱️  AVERAGE FLOW DURATION")
print("=" * 50)
print(avg_flow)

print("\n")

print("=" * 50)
print("   📦 AVERAGE PACKET LENGTH MEAN")
print("=" * 50)
print(avg_packet)
# Out:
# ...
#    ⏱️  AVERAGE FLOW DURATION
# ...
# Label
# Attack            8.909046e+06
# Normal Traffic    8.966348e+06
# Name: Flow Duration, dtype: float64
#
#
# ...
#    📦 AVERAGE PACKET LENGTH MEAN
# ...
# Label
# Attack            85.573255
# Normal Traffic    85.542480
# Name: Packet Length Mean, dtype: float64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

ax1.pie(avg_flow.values, labels=avg_flow.index,
        colors=['#c9b8f5', '#f5b8d0'], autopct='%1.1f%%')
ax1.set_title('Average Flow Duration by Label')

ax2.pie(avg_packet.values, labels=avg_packet.index,
        colors=['#c9b8f5', '#f5b8d0'], autopct='%1.1f%%')
ax2.set_title('Average Packet Length Mean by Label')

plt.show()

# %%
normal = df_filtered[df_filtered['Label'] == 'Normal Traffic']['Fwd Packet Length Mean']
attack = df_filtered[df_filtered['Label'] == 'Attack']['Fwd Packet Length Mean']

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(6, 3))
plt.boxplot([normal, attack], labels=['Normal Traffic', 'Attack'])
plt.title('Fwd Packet Length Mean by Label')
plt.xlabel('Label')
plt.ylabel('Fwd Packet Length Mean')
plt.show()

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Playfair+Display:ital,wght@0,700;1,400&display=swap" rel="stylesheet"/>
#
# <h1 style="text-align: center; font-family: 'Playfair Display', serif; font-size: 64px; margin: 0;">
#   <span style="font-weight: 700; color: inherit;">Dash </span>
#   <span style="font-style: italic; color: #b85c38;">Board</span>
# </h1>

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 7))
fig.suptitle('Network Traffic Data Analysis Dashboard', fontsize=16, fontweight='bold')

# ---- Chart 1: Bar Chart ----
ax1 = fig.add_subplot(2, 2, 1)
ax1.bar(label_counts.index, label_counts.values, color=['#c9b8f5', '#f5b8d0'], width=0.5)
ax1.set_title(' Label Frequency')
ax1.set_xlabel('Label')
ax1.set_ylabel('Frequency')
ax1.grid(axis='y', linestyle='--', alpha=0.4)

# ---- Chart 2: Boxplot ----
ax2 = fig.add_subplot(2, 2, 2)
ax2.boxplot([normal, attack], labels=['Normal Traffic', 'Attack'])
ax2.set_title(' Fwd Packet Length Mean')
ax2.set_xlabel('Label')
ax2.set_ylabel('Fwd Packet Length Mean')
ax2.grid(axis='y', linestyle='--', alpha=0.4)

# ---- Chart 3: Pie Chart - Packet Length ----
ax3 = fig.add_subplot(2, 2, 3)
ax3.pie(avg_packet.values, labels=avg_packet.index, colors=['#c9b8f5', '#f5b8d0'], autopct='%1.1f%%')
ax3.set_title(' Average Packet Length Mean')

# ---- Chart 4: Pie Chart - Flow Duration ----
ax4 = fig.add_subplot(2, 2, 4)
ax4.pie(avg_flow.values, labels=avg_flow.index, colors=['#c9b8f5', '#f5b8d0'], autopct='%1.1f%%')
ax4.set_title(' Average Flow Duration' )

plt.tight_layout()
plt.show()

# %%
from scipy import stats

# %%
normal = df_filtered[df_filtered['Label'] == 'Normal Traffic']['Flow Duration']
attack = df_filtered[df_filtered['Label'] == 'Attack']['Flow Duration']

# %%
t_stat, p_value = stats.ttest_ind(normal, attack)

# %%
print("=" * 50)
print("   📊 T-STATISTIC")
print("=" * 50)
print(t_stat)

print("\n")

print("=" * 50)
print("   📉 P-VALUE")
print("=" * 50)
print(p_value)
# Out:
# ...
#    📊 T-STATISTIC
# ...
# 0.7161327588416806
#
#
# ...
#    📉 P-VALUE
# ...
# 0.473909720385436

# %%
print("=" * 50)
print("   🔬 HYPOTHESIS TEST RESULT")
print("=" * 50)
if p_value < 0.05:
    print("   ✅ Result: Reject Null Hypothesis")
    print("   There is a significant difference")
else:
    print("   ❌ Result: Accept Null Hypothesis")
    print("   There is no significant difference")
# Out:
# ...
#    🔬 HYPOTHESIS TEST RESULT
# ...
#    ❌ Result: Accept Null Hypothesis
#    There is no significant difference

# %% [markdown]
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.5.0/css/all.min.css"/>
# <link href="https://fonts.googleapis.com/css2?family=Cormorant+Garamond:ital,wght@0,600;1,400&display=swap" rel="stylesheet"/>
# <div style="font-family: sans-serif; padding: 16px; background: #f7f5f0; border-radius: 16px; max-width: 320px; margin: 0 auto; text-align: center;">
# <h2 style="font-family: 'Cormorant Garamond', serif; font-size: 38px; font-weight: 600; color: inherit; margin: 0 0 16px 0;">Akisha <em style="font-style: italic; color: #2d5a4f;">Bhujel</em></h2><hr style="border: none; border-top: 1px solid #e2ddd7; margin: 0 auto 12px; max-width: 180px;"/>
# <p style="font-size: 11px; letter-spacing: 0.18em; text-transform: uppercase; color: #999; margin: 0 auto 12px; text-align: center;">Find me online</p>
# <a href="https://github.com/akisavujel" target="_blank" style="display: inline-block; text-decoration: none; color: #1c1c1c; font-size: 14px; margin: 6px 12px;"><i class="fa-brands fa-github" style="color: #2d5a4f;"></i> GitHub</a>
# <a href="https://www.kaggle.com/akisavujel" target="_blank" style="display: inline-block; text-decoration: none; color: #1c1c1c; font-size: 14px; margin: 6px 12px;"><i class="fa-brands fa-kaggle" style="color: #2d5a4f;"></i> Kaggle</a>
# <a href="https://hashnode.com/@akisavujel" target="_blank" style="display: inline-block; text-decoration: none; color: #1c1c1c; font-size: 14px; margin: 6px 12px;"><i class="fa-brands fa-hashnode" style="color: #2d5a4f;"></i> Hashnode</a>
# <a href="https://www.linkedin.com/in/akishabhujel/" target="_blank" style="display: inline-block; text-decoration: none; color: #1c1c1c; font-size: 14px; margin: 6px 12px;"><i class="fa-brands fa-linkedin" style="color: #2d5a4f;"></i> LinkedIn</a>
# <a href="mailto:akishabhujel@gmail.com" style="display: inline-block; text-decoration: none; color: #1c1c1c; font-size: 14px; margin: 6px 12px;"><i class="fa-solid fa-envelope" style="color: #2d5a4f;"></i> Email</a>
# <a href="https://akisavujel.github.io/Portfolio/" target="_blank" style="display: inline-block; text-decoration: none; color: #1c1c1c; font-size: 14px; margin: 6px 12px;"><i class="fa-solid fa-globe" style="color: #2d5a4f;"></i> Portfolio</a>
# <hr style="border: none; border-top: 1px solid #e2ddd7; margin: 12px auto; max-width: 180px;"/>
# <img src="https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExZzUxMWs3YXU5OXgwYm4wdDJwanQ5aTMyOG1sa215cDN4Nml6aXJnbSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/L9Q2rzzBHrfv4a1y4h/giphy.gif" style="width: 150px; border-radius: 12px; display: block; margin: 0 auto;"/></div>
